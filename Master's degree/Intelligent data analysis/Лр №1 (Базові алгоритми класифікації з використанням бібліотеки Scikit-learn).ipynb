# %%
import pandas as pd
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# ## 1) Завантажити дані, вивести назви колонок і розмір датасета

# %%
df = pd.read_csv("cybersecurity_attacks.csv")  # https://www.kaggle.com/datasets/teamincribo/cyber-security-attacks/

df.sample(5).T
# Out:
#                                                                     12858  \
# Timestamp                                             2021-09-16 15:11:12
# Source IP Address                                           181.83.42.138
# Destination IP Address                                     130.19.220.232
# Source Port                                                         40673
# Destination Port                                                    10664
# Protocol                                                              TCP
# Packet Length                                                         475
# Packet Type                                                          Data
# Traffic Type                                                         HTTP
# Payload Data            Tempore at asperiores molestias delectus tempo...
# Malware Indicators                                                    NaN
# Anomaly Scores                                                      43.74
# Alerts/Warnings                                           Alert Triggered
# Attack Type                                                       Malware
# Attack Signature                                          Known Pattern B
# Action Taken                                                      Ignored
# Severity Level                                                       High
# User Information                                              Sahil Dubey
# Device Information      Mozilla/5.0 (compatible; MSIE 8.0; Windows 98;...
# Network Segment                                                 Segment B
# Geo-location Data                                         Bhopal, Gujarat
# Proxy Information                                           82.100.170.27
# Firewall Logs                                                    Log Data
# IDS/IPS Alerts                                                 Alert Data
# Log Source                                                         Server
#
#                                                                     69     \
# Timestamp                                             2020-09-13 01:49:45
# Source IP Address                                         185.157.240.136
# Destination IP Address                                      107.0.155.243
# Source Port                                                          5107
# Destination Port                                                    60905
# Protocol                                                             ICMP
# Packet Length                                                         995
# Packet Type                                                       Control
# Traffic Type                                                          DNS
# Payload Data            Nobis illo incidunt atque amet ex recusandae. ...
# Malware Indicators                                                    NaN
# Anomaly Scores                                                      51.66
# Alerts/Warnings                                           Alert Triggered
# Attack Type                                                       Malware
# Attack Signature                                          Known Pattern A
# Action Taken                                                       Logged
# Severity Level                                                       High
# User Information                                            Shray Agrawal
# Device Information      Opera/9.38.(Windows 95; tn-ZA) Presto/2.9.189 ...
# Network Segment                                                 Segment C
# Geo-location Data                                Bangalore, Uttar Pradesh
# Proxy Information                                             98.8.33.127
# Firewall Logs                                                    Log Data
# IDS/IPS Alerts                                                        NaN
# Log Source                                                       Firewall
#
#                                                                     14669  \
# Timestamp                                             2023-08-22 02:47:46
# Source IP Address                                           7.102.202.197
# Destination IP Address                                      81.179.240.65
# Source Port                                                         63704
# Destination Port                                                    20099
# Protocol                                                              UDP
# Packet Length                                                        1262
# Packet Type                                                       Control
# Traffic Type                                                         HTTP
# Payload Data            Excepturi perspiciatis dignissimos nisi. Enim ...
# Malware Indicators                                                    NaN
# Anomaly Scores                                                      53.77
# Alerts/Warnings                                                       NaN
# Attack Type                                                          DDoS
# Attack Signature                                          Known Pattern A
# Action Taken                                                       Logged
# Severity Level                                                     Medium
# User Information                                            Sahil Ganesan
# Device Information      Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_5...
# Network Segment                                                 Segment B
# Geo-location Data                                          Rajkot, Odisha
# Proxy Information                                            34.16.185.75
# Firewall Logs                                                    Log Data
# IDS/IPS Alerts                                                        NaN
# Log Source                                                         Server
#
#                                                                     30416  \
# Timestamp                                             2023-04-04 04:50:43
# Source IP Address                                         191.116.151.188
# Destination IP Address                                         2.19.183.6
# Source Port                                                         62206
# Destination Port                                                    17287
# Protocol                                                              TCP
# Packet Length                                                         507
# Packet Type                                                       Control
# Traffic Type                                                         HTTP
# Payload Data            Eligendi harum in occaecati. Soluta odio hic i...
# Malware Indicators                                                    NaN
# Anomaly Scores                                                      53.92
# Alerts/Warnings                                                       NaN
# Attack Type                                                     Intrusion
# Attack Signature                                          Known Pattern B
# Action Taken                                                      Blocked
# Severity Level                                                     Medium
# User Information                                           Uthkarsh Comar
# Device Information      Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_9_0...
# Network Segment                                                 Segment B
# Geo-location Data                                   Raebareli, Tamil Nadu
# Proxy Information                                                     NaN
# Firewall Logs                                                    Log Data
# IDS/IPS Alerts                                                        NaN
# Log Source                                                         Server
#
#                                                                     27494
# Timestamp                                             2021-07-07 21:25:04
# Source IP Address                                            187.2.60.248
# Destination IP Address                                       185.17.31.46
# Source Port                                                         11572
# Destination Port                                                    14584
# Protocol                                                              UDP
# Packet Length                                                         601
# Packet Type                                                       Control
# Traffic Type                                                         HTTP
# Payload Data            Vitae eveniet vero nemo dolorem laboriosam ali...
# Malware Indicators                                           IoC Detected
# Anomaly Scores                                                      38.47
# Alerts/Warnings                                           Alert Triggered
# Attack Type                                                     Intrusion
# Attack Signature                                          Known Pattern B
# Action Taken                                                       Logged
# Severity Level                                                        Low
# User Information                                          Divyansh Mannan
# Device Information      Mozilla/5.0 (iPod; U; CPU iPhone OS 3_1 like M...
# Network Segment                                                 Segment C
# Geo-location Data                                    Chinsurah, Jharkhand
# Proxy Information                                                     NaN
# Firewall Logs                                                    Log Data
# IDS/IPS Alerts                                                 Alert Data
# Log Source                                                         Server

# %%
print(f"List of column names:", df.columns, "\n")

print(f"There are {df.shape[0]} rows and {df.shape[1]} columns in the dataset")
# Out:
# List of column names: Index(['Timestamp', 'Source IP Address', 'Destination IP Address',
#        'Source Port', 'Destination Port', 'Protocol', 'Packet Length',
#        'Packet Type', 'Traffic Type', 'Payload Data', 'Malware Indicators',
#        'Anomaly Scores', 'Alerts/Warnings', 'Attack Type', 'Attack Signature',
#        'Action Taken', 'Severity Level', 'User Information',
#        'Device Information', 'Network Segment', 'Geo-location Data',
#        'Proxy Information', 'Firewall Logs', 'IDS/IPS Alerts', 'Log Source'],
#       dtype='object')
#
# There are 40000 rows and 25 columns in the dataset

# %% [markdown]
# ## 2) Опрацювати пропуски (по можливості заповнити їх або видалити)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               40000 non-null  object
#  1   Source IP Address       40000 non-null  object
#  2   Destination IP Address  40000 non-null  object
#  3   Source Port             40000 non-null  int64
#  4   Destination Port        40000 non-null  int64
#  5   Protocol                40000 non-null  object
#  6   Packet Length           40000 non-null  int64
#  7   Packet Type             40000 non-null  object
#  8   Traffic Type            40000 non-null  object
#  9   Payload Data            40000 non-null  object
#  10  Malware Indicators      20000 non-null  object
#  11  Anomaly Scores          40000 non-null  float64
#  12  Alerts/Warnings         19933 non-null  object
#  13  Attack Type             40000 non-null  object
#  14  Attack Signature        40000 non-null  object
#  15  Action Taken            40000 non-null  object
#  16  Severity Level          40000 non-null  object
#  17  User Information        40000 non-null  object
#  18  Device Information      40000 non-null  object
#  19  Network Segment         40000 non-null  object
#  20  Geo-location Data       40000 non-null  object
#  21  Proxy Information       20149 non-null  object
#  22  Firewall Logs           20039 non-null  object
#  23  IDS/IPS Alerts          19950 non-null  object
#  24  Log Source              40000 non-null  object
# dtypes: float64(1), int64(3), object(21)
# memory usage: 7.6+ MB

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Timestamp                  0.0000
# Source IP Address          0.0000
# Destination IP Address     0.0000
# Source Port                0.0000
# Destination Port           0.0000
# Protocol                   0.0000
# Packet Length              0.0000
# Packet Type                0.0000
# Traffic Type               0.0000
# Payload Data               0.0000
# Malware Indicators        50.0000
# Anomaly Scores             0.0000
# Alerts/Warnings           50.1675
# Attack Type                0.0000
# Attack Signature           0.0000
# Action Taken               0.0000
# Severity Level             0.0000
# User Information           0.0000
# Device Information         0.0000
# Network Segment            0.0000
# Geo-location Data          0.0000
# Proxy Information         49.6275
# Firewall Logs             49.9025
# IDS/IPS Alerts            50.1250
# Log Source                 0.0000
# dtype: float64

# %%
df['Malware Indicators'] = df['Malware Indicators'].apply(lambda x: 'Nothing Detected' if pd.isna(x) else x)
df['Alerts/Warnings'] = df['Alerts/Warnings'].apply(lambda x: 'Yes' if x == 'Alert Triggered' else 'No')
df['Proxy Information'] = df['Proxy Information'].apply(lambda x: 'Without Proxy' if pd.isna(x) else x)
df['Firewall Logs'] = df['Firewall Logs'].apply(lambda x: 'Not Logged' if pd.isna(x) else x)
df['IDS/IPS Alerts'] = df['IDS/IPS Alerts'].apply(lambda x: 'Not Alerted' if pd.isna(x) else x)

# %%
for column in df.columns:
    unique_values = set(df[column])
    if len(unique_values) <= 10:
        print(f"Unique values in column '{column}' ({len(unique_values)}): {unique_values}")
    else:
        print(f"Column '{column}' has more than 10 unique values: {len(unique_values)}")
# Out:
# Column 'Timestamp' has more than 10 unique values: 39997
# Column 'Source IP Address' has more than 10 unique values: 40000
# Column 'Destination IP Address' has more than 10 unique values: 40000
# Column 'Source Port' has more than 10 unique values: 29761
# Column 'Destination Port' has more than 10 unique values: 29895
# Unique values in column 'Protocol' (3): {'TCP', 'UDP', 'ICMP'}
# Column 'Packet Length' has more than 10 unique values: 1437
# Unique values in column 'Packet Type' (2): {'Control', 'Data'}
# Unique values in column 'Traffic Type' (3): {'DNS', 'FTP', 'HTTP'}
# Column 'Payload Data' has more than 10 unique values: 40000
# Unique values in column 'Malware Indicators' (2): {'IoC Detected', 'Nothing Detected'}
# Column 'Anomaly Scores' has more than 10 unique values: 9826
# Unique values in column 'Alerts/Warnings' (2): {'Yes', 'No'}
# Unique values in column 'Attack Type' (3): {'Intrusion', 'DDoS', 'Malware'}
# Unique values in column 'Attack Signature' (2): {'Known Pattern B', 'Known Pattern A'}
# Unique values in column 'Action Taken' (3): {'Logged', 'Ignored', 'Blocked'}
# Unique values in column 'Severity Level' (3): {'Low', 'High', 'Medium'}
# Column 'User Information' has more than 10 unique values: 32389
# Column 'Device Information' has more than 10 unique values: 32104
# Unique values in column 'Network Segment' (3): {'Segment C', 'Segment B', 'Segment A'}
# Column 'Geo-location Data' has more than 10 unique values: 8723
# Column 'Proxy Information' has more than 10 unique values: 20149
# Unique values in column 'Firewall Logs' (2): {'Not Logged', 'Log Data'}
# Unique values in column 'IDS/IPS Alerts' (2): {'Not Alerted', 'Alert Data'}
# Unique values in column 'Log Source' (2): {'Firewall', 'Server'}

# %%
null_counts = df.isnull().sum().sort_values(ascending=False)

if null_counts.sum() == 0:
    print("There are no missing values in the dataset.")
else:
    print("There are missing values in the dataset.")
# Out:
# There are no missing values in the dataset.

# %% [markdown]
# ## 3) Візуаліузвати дані

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
related_features = ['IDS/IPS Alerts', 'Protocol', 'Traffic Type', 'Malware Indicators', 
                    'Anomaly Scores', 'Severity Level', 'Action Taken', 'Attack Type']

categorical_columns = ['Protocol', 'Traffic Type', 'Malware Indicators', 
                       'Severity Level', 'Action Taken', 'Attack Type']

df_encoded = pd.get_dummies(df[related_features], columns=categorical_columns)

df_encoded['IDS/IPS Alerts'] = df_encoded['IDS/IPS Alerts'].apply(lambda x: 1 if x == 'Alert Data' else 0)

# %%
df_encoded.sample(10).T
# Out:
#                                      11055  10489  27240  12117  23230  28236  \
# IDS/IPS Alerts                        0.00    1.0   1.00   0.00   1.00   0.00
# Anomaly Scores                       82.78   48.4  36.22  16.51  41.46  62.45
# Protocol_ICMP                         1.00    0.0   0.00   0.00   1.00   0.00
# Protocol_TCP                          0.00    1.0   1.00   0.00   0.00   0.00
# Protocol_UDP                          0.00    0.0   0.00   1.00   0.00   1.00
# Traffic Type_DNS                      0.00    1.0   1.00   0.00   1.00   0.00
# Traffic Type_FTP                      0.00    0.0   0.00   1.00   0.00   0.00
# Traffic Type_HTTP                     1.00    0.0   0.00   0.00   0.00   1.00
# Malware Indicators_IoC Detected       1.00    0.0   1.00   0.00   1.00   1.00
# Malware Indicators_Nothing Detected   0.00    1.0   0.00   1.00   0.00   0.00
# Severity Level_High                   1.00    0.0   1.00   0.00   0.00   0.00
# Severity Level_Low                    0.00    1.0   0.00   0.00   1.00   0.00
# Severity Level_Medium                 0.00    0.0   0.00   1.00   0.00   1.00
# Action Taken_Blocked                  0.00    0.0   0.00   0.00   0.00   0.00
# Action Taken_Ignored                  1.00    1.0   0.00   0.00   1.00   0.00
# Action Taken_Logged                   0.00    0.0   1.00   1.00   0.00   1.00
# Attack Type_DDoS                      0.00    0.0   1.00   0.00   0.00   0.00
# Attack Type_Intrusion                 0.00    1.0   0.00   1.00   0.00   0.00
# Attack Type_Malware                   1.00    0.0   0.00   0.00   1.00   1.00
#
#                                      12660  26871  28425  12704
# IDS/IPS Alerts                        0.00   0.00    0.0   1.00
# Anomaly Scores                       46.74  98.82   13.9   1.33
# Protocol_ICMP                         1.00   1.00    0.0   0.00
# Protocol_TCP                          0.00   0.00    1.0   1.00
# Protocol_UDP                          0.00   0.00    0.0   0.00
# Traffic Type_DNS                      1.00   1.00    0.0   0.00
# Traffic Type_FTP                      0.00   0.00    0.0   1.00
# Traffic Type_HTTP                     0.00   0.00    1.0   0.00
# Malware Indicators_IoC Detected       0.00   0.00    1.0   1.00
# Malware Indicators_Nothing Detected   1.00   1.00    0.0   0.00
# Severity Level_High                   0.00   1.00    1.0   0.00
# Severity Level_Low                    1.00   0.00    0.0   0.00
# Severity Level_Medium                 0.00   0.00    0.0   1.00
# Action Taken_Blocked                  0.00   0.00    1.0   1.00
# Action Taken_Ignored                  0.00   0.00    0.0   0.00
# Action Taken_Logged                   1.00   1.00    0.0   0.00
# Attack Type_DDoS                      1.00   0.00    1.0   1.00
# Attack Type_Intrusion                 0.00   0.00    0.0   0.00
# Attack Type_Malware                   0.00   1.00    0.0   0.00

# %% [markdown]
# - Побудувати графік (heatmap), що відображає кореляці
# ознак між собою і з цільовою змінною (розміткою)

# %%
plt.figure(figsize=(12, 10))
correlation_matrix = df_encoded.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

plt.title('Correlation Heatmap of Features with IDS/IPS Alerts')
plt.show()

# %% [markdown]
# - Побудувати гістограми розподілу ознак

# %%
df.hist(bins=60, figsize=(20, 8), color='skyblue', edgecolor='black')
plt.suptitle('Histograms of the distribution of numerical features')
plt.show()

plt.figure(figsize=(20, 20))
for i, column in enumerate(df[categorical_columns].columns, 1):
    plt.subplot(4, 2, i)  # налаштовуємо розміщення кількох графіків на одній сторінці
    sns.histplot(df[column], kde=False, color='skyblue', edgecolor='black')
    plt.title(column)
    plt.tight_layout()
plt.suptitle('Histograms of the distribution of coded categorical features', y=1.02)
plt.show()

# %% [markdown]
# - Побудувати boxplot-и ознак відносно цільової змінної (якщо ознак занадто багато обмежитися декількома)

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='Attack Type', y='Anomaly Scores', data=df)

plt.title('Boxplot of Anomaly Scores by Attack Type')
plt.show()

# %% [markdown]
# ## 4) Нормалізувати дані

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
numerical_features = ['Anomaly Scores', 'Packet Length']
df[numerical_features] = scaler.fit_transform(df[numerical_features])

df.sample(5).T
# Out:
#                                                                     28878  \
# Timestamp                                             2020-10-21 12:31:06
# Source IP Address                                           183.14.95.209
# Destination IP Address                                       42.115.112.2
# Source Port                                                         63019
# Destination Port                                                    35595
# Protocol                                                              TCP
# Packet Length                                                   -0.376053
# Packet Type                                                       Control
# Traffic Type                                                          FTP
# Payload Data            Soluta maxime enim unde incidunt ut. Laboriosa...
# Malware Indicators                                       Nothing Detected
# Anomaly Scores                                                  -1.308812
# Alerts/Warnings                                                       Yes
# Attack Type                                                     Intrusion
# Attack Signature                                          Known Pattern A
# Action Taken                                                       Logged
# Severity Level                                                       High
# User Information                                             Nirvi Butala
# Device Information      Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_8_6...
# Network Segment                                                 Segment C
# Geo-location Data                                     Junagadh, Jharkhand
# Proxy Information                                           57.78.242.242
# Firewall Logs                                                  Not Logged
# IDS/IPS Alerts                                                Not Alerted
# Log Source                                                       Firewall
#
#                                                                     20896  \
# Timestamp                                             2022-04-25 02:28:13
# Source IP Address                                            36.60.115.64
# Destination IP Address                                     155.218.189.77
# Source Port                                                         11574
# Destination Port                                                     5350
# Protocol                                                              TCP
# Packet Length                                                   -0.190974
# Packet Type                                                          Data
# Traffic Type                                                          FTP
# Payload Data            Ipsa cum amet. Et qui laudantium sequi nisi as...
# Malware Indicators                                       Nothing Detected
# Anomaly Scores                                                    0.47227
# Alerts/Warnings                                                        No
# Attack Type                                                     Intrusion
# Attack Signature                                          Known Pattern B
# Action Taken                                                       Logged
# Severity Level                                                       High
# User Information                                                Pihu Chad
# Device Information      Mozilla/5.0 (Windows NT 6.0; ru-UA; rv:1.9.0.2...
# Network Segment                                                 Segment B
# Geo-location Data                                    Coimbatore, Nagaland
# Proxy Information                                           Without Proxy
# Firewall Logs                                                  Not Logged
# IDS/IPS Alerts                                                Not Alerted
# Log Source                                                         Server
#
#                                                                     10177  \
# Timestamp                                             2021-02-03 18:34:26
# Source IP Address                                          177.150.141.53
# Destination IP Address                                       2.175.79.180
# Source Port                                                          1310
# Destination Port                                                    29979
# Protocol                                                             ICMP
# Packet Length                                                   -1.260586
# Packet Type                                                          Data
# Traffic Type                                                          FTP
# Payload Data            Veritatis iure repellendus tempora veniam dolo...
# Malware Indicators                                       Nothing Detected
# Anomaly Scores                                                   0.830636
# Alerts/Warnings                                                       Yes
# Attack Type                                                     Intrusion
# Attack Signature                                          Known Pattern B
# Action Taken                                                      Ignored
# Severity Level                                                        Low
# User Information                                            Stuvan Shetty
# Device Information      Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# Network Segment                                                 Segment B
# Geo-location Data                                           Shimla, Bihar
# Proxy Information                                           Without Proxy
# Firewall Logs                                                  Not Logged
# IDS/IPS Alerts                                                 Alert Data
# Log Source                                                         Server
#
#                                                                     5054   \
# Timestamp                                             2020-09-20 15:59:00
# Source IP Address                                           10.85.217.218
# Destination IP Address                                        21.69.89.61
# Source Port                                                         19316
# Destination Port                                                    56036
# Protocol                                                             ICMP
# Packet Length                                                    0.145533
# Packet Type                                                       Control
# Traffic Type                                                          DNS
# Payload Data            Amet adipisci vitae sed. Amet doloremque accus...
# Malware Indicators                                       Nothing Detected
# Anomaly Scores                                                  -0.227131
# Alerts/Warnings                                                        No
# Attack Type                                                          DDoS
# Attack Signature                                          Known Pattern A
# Action Taken                                                      Ignored
# Severity Level                                                       High
# User Information                                               Divit Vora
# Device Information      Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.0...
# Network Segment                                                 Segment B
# Geo-location Data                                       Hyderabad, Sikkim
# Proxy Information                                          186.91.121.178
# Firewall Logs                                                    Log Data
# IDS/IPS Alerts                                                Not Alerted
# Log Source                                                       Firewall
#
#                                                                     33925
# Timestamp                                             2022-06-30 23:07:22
# Source IP Address                                          154.95.125.196
# Destination IP Address                                     48.239.175.147
# Source Port                                                         15133
# Destination Port                                                    55535
# Protocol                                                             ICMP
# Packet Length                                                   -0.892832
# Packet Type                                                       Control
# Traffic Type                                                         HTTP
# Payload Data            Cumque harum maxime recusandae. Impedit eum er...
# Malware Indicators                                       Nothing Detected
# Anomaly Scores                                                  -0.663131
# Alerts/Warnings                                                        No
# Attack Type                                                     Intrusion
# Attack Signature                                          Known Pattern B
# Action Taken                                                      Ignored
# Severity Level                                                       High
# User Information                                                Umang Sem
# Device Information      Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# Network Segment                                                 Segment A
# Geo-location Data                                  Farrukhabad, Karnataka
# Proxy Information                                            199.46.88.38
# Firewall Logs                                                  Not Logged
# IDS/IPS Alerts                                                Not Alerted
# Log Source                                                       Firewall

# %% [markdown]
# ## 5) Провести навчання класифікаторів

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
X = df_encoded[['Severity Level_Low', 'Severity Level_Medium', 'Severity Level_High']]
y = df_encoded['IDS/IPS Alerts']

# Розділяємо дані на тренувальну та тестову вибірки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# - kNN

# %%
error_rate = []

for i in range(1,30):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))

plt.figure(figsize=(10,6))
plt.plot(range(1,30), error_rate, marker='o', markersize=8, color='m')
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
plt.grid()

# %%
knn = KNeighborsClassifier(n_neighbors=4)
params_knn = {'n_neighbors': range(1, 15)}
grid_knn = GridSearchCV(knn, param_grid=params_knn, cv=5)
grid_knn.fit(X_train, y_train)
y_pred_knn = grid_knn.predict(X_test)

print("kNN Classification Report")
print(classification_report(y_test, y_pred_knn))
print("kNN Confusion Matrix")
print(confusion_matrix(y_test, y_pred_knn))
# Out:
# kNN Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.66      0.57      6050
#            1       0.49      0.33      0.39      5950
#
#     accuracy                           0.49     12000
#    macro avg       0.49      0.49      0.48     12000
# weighted avg       0.49      0.49      0.48     12000
#
# kNN Confusion Matrix
# [[3969 2081]
#  [3985 1965]]

# %% [markdown]
# - Decision Tree

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)

print("Decision Tree Classification Report")
print(classification_report(y_test, y_pred_dt))
print("Decision Tree Confusion Matrix")
print(confusion_matrix(y_test, y_pred_dt))
# Out:
# Decision Tree Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.66      0.57      6050
#            1       0.49      0.33      0.40      5950
#
#     accuracy                           0.50     12000
#    macro avg       0.50      0.50      0.48     12000
# weighted avg       0.50      0.50      0.49     12000
#
# Decision Tree Confusion Matrix
# [[4011 2039]
#  [3969 1981]]

# %%
plt.figure(figsize = (12, 8))
plot_tree(dt, filled = True)
plt.show()

# %% [markdown]
# - SVM

# %%
svm = SVC()
params_svm = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001]}
grid_svm = GridSearchCV(svm, param_grid=params_svm, cv=5)
grid_svm.fit(X_train, y_train)
y_pred_svm = grid_svm.predict(X_test)

print("SVM Classification Report")
print(classification_report(y_test, y_pred_svm))
print("SVM Confusion Matrix")
print(confusion_matrix(y_test, y_pred_svm))
# Out:
# SVM Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.66      0.57      6050
#            1       0.49      0.33      0.40      5950
#
#     accuracy                           0.50     12000
#    macro avg       0.50      0.50      0.48     12000
# weighted avg       0.50      0.50      0.49     12000
#
# SVM Confusion Matrix
# [[4011 2039]
#  [3969 1981]]

# %% [markdown]
# - Random Forest

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("Random Forest Classification Report")
print(classification_report(y_test, y_pred_rf))
print("Random Forest Confusion Matrix")
print(confusion_matrix(y_test, y_pred_rf))
# Out:
# Random Forest Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.66      0.57      6050
#            1       0.49      0.33      0.40      5950
#
#     accuracy                           0.50     12000
#    macro avg       0.50      0.50      0.48     12000
# weighted avg       0.50      0.50      0.49     12000
#
# Random Forest Confusion Matrix
# [[4011 2039]
#  [3969 1981]]

# %% [markdown]
# - AdaBoost

# %%
ada = AdaBoostClassifier(random_state=42)
ada.fit(X_train, y_train)
y_pred_ada = ada.predict(X_test)

print("AdaBoost Classification Report")
print(classification_report(y_test, y_pred_ada))
print("AdaBoost Confusion Matrix")
print(confusion_matrix(y_test, y_pred_ada))
# Out:
# AdaBoost Classification Report
#               precision    recall  f1-score   support
#
#            0       0.50      0.66      0.57      6050
#            1       0.49      0.33      0.40      5950
#
#     accuracy                           0.50     12000
#    macro avg       0.50      0.50      0.48     12000
# weighted avg       0.50      0.50      0.49     12000
#
# AdaBoost Confusion Matrix
# [[4011 2039]
#  [3969 1981]]
